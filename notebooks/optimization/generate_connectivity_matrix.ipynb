# %%
import numpy as np
import nest 
from scripts import visualizations, initializations
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.6.0
#  Built: Sep 28 2023 11:53:34
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
#Define the parameters (empty for now)

# %%
#Generates the matrix
matrix = initializations.initialize_connectivity_matrix_hardcoded()

# %%
#Plot the matrix
visualizations.plot_matrix(matrix)

# %%
#Saves the matrix
np.save('/hpc/mzhu843/modelling/nest/DATA/matrices/initial_matrix', matrix)
